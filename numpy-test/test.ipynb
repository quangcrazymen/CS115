# %%
import numpy as np
import matplotlib.pyplot as plt
# Trace is sum of diagonal elements

a = np.array([[1,2,3],[12,34,52]])
b =np.array([1,2,3,5])
c = np.array([1,2,4,6])
print(np.dot(b,c))
print(b@c)
print(np.trace(a))

from sklearn.datasets import make_regression
X,y = make_regression(n_samples=300,n_features=1,n_informative=1,noise=25,random_state=42)

plt.scatter(X,y,facecolor='tab:blue',edgecolors='white',s=70)
plt.xlabel('X')
plt.ylabel('y')
plt.show()
# Out:
# 47
# 47
# 35

# %% [markdown]
# $\forall x \in X, \quad \exists y \leq \epsilon$
